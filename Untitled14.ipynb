# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid')

# %%
crude=pd.read_csv('D:\\python\\Titanic_ML\\petrolIndia\\Indian petrolium product prices - crude oil price.csv')

# %%
crude.shape
# Out:
# (119, 3)

# %%
diesel=pd.read_csv('D:\\python\\Titanic_ML\\petrolIndia\\Indian petrolium product prices - Diesel.csv')

# %%
diesel.shape
# Out:
# (281, 5)

# %%
diesel.tail(10)
# Out:
#            Date  Delhi  Kolkata  Mumbai  Chennai
# 271  01/11/2002  19.25    20.64   24.56    21.18
# 272  17/10/2002  19.23    20.62   24.54    21.16
# 273  01/10/2002  18.91    20.30   23.97    20.81
# 274  16/09/2002  18.68    20.06   23.69    20.55
# 275  01/09/2002  18.34    19.72   23.29    20.18
# 276  16/08/2002  18.05    18.43   22.95    19.86
# 277  01/08/2002  18.23    18.16   23.16    20.06
# 278  01/07/2002  18.23    18.61   23.16    20.06
# 279  16/06/2002  18.23    18.61   23.14    19.88
# 280  04/06/2002  17.99    18.38   22.84    19.63

# %%
pp=pd.read_csv('D:\\python\\Titanic_ML\\petrolIndia\\Indian petrolium product prices - non-subsidised cylinder.csv')

# %%
pp.tail(10)
# Out:
#                  Date   Delhi Kolkata  Mumbai Chennai
# 44      July 01, 2014   922.5     966   949.5     924
# 45      June 25, 2014     906     946   933.0     905
# 46       June 1, 2014     905     946   933.0     905
# 47        May 1, 2014   928.5     970   957.0   928.5
# 48      April 1, 2014   980.5  1017.5  1011.0     981
# 49     March 31, 2014  1080.5    1118  1115.5  1081.5
# 50  February 28, 2014    1134    1169  1167.5    1132
# 51   January 31, 2014    1241    1270  1273.0    1234
# 52    January 4, 2014    1241    1270  1264.5    1234
# 53  December 11, 2013    1021  1050.5  1038.0    1014

# %%
lpgSubd=pd.read_csv('D:\\python\\Titanic_ML\\petrolIndia\\Indian petrolium product prices - Subsidised.csv')

# %%
lpgSubd.tail(10)
# Out:
#                  Date   Delhi Kolkata  Mumbai Chennai
# 70   January 29, 2009   279.7  327.05  312.05  314.55
# 71      June 09, 2008   304.7  352.05  349.50   339.6
# 72      June 09, 2008   304.7  352.05  349.50   339.6
# 73      June 05, 2008   346.3  352.05  349.50   339.6
# 74     March 01, 2007  294.75   300.5  298.00   288.1
# 75     April 01, 2005  294.75   300.5  297.95  288.15
# 76  November 05, 2004   281.6  309.65  291.85  288.15
# 77      July 01, 2004   261.6  287.95  271.30   268.1
# 78      June 16, 2004   261.6  287.95  271.30   268.1
# 79   January 01, 2004   241.6   266.7  251.00  248.55

# %%
x=lpgSubd.iloc[:10]

# %%
x
# Out:
#                Date      Delhi    Kolkata  Mumbai    Chennai
# 0    August 01,2017     479.77     482.58  482.08     467.35
# 1      July 11,2017  No Change  No Change  480.27  No Change
# 2      July 01,2017     477.46     480.32  491.25     465.56
# 3      June 01,2017     446.65     448.65  476.97     434.15
# 4       May 01,2017     442.77     444.77  475.56     430.27
# 5     April 01,2017      440.9      442.9  476.50      428.4
# 6     March 01,2017     434.93     436.93  470.66     422.43
# 7  February 01,2017      434.8      436.8  467.95      422.3
# 8   January 01,2017     434.71     436.71  465.88     422.21
# 9  December 01,2016     432.71     434.71  463.91     420.21

# %%
lpgSubd.isnull().sum()
# Out:
# Date       0
# Delhi      0
# Kolkata    0
# Mumbai     0
# Chennai    0
# dtype: int64

# %%
lpgSubd.Delhi.isnull().value_counts()
# Out:
# False    80
# Name: Delhi, dtype: int64

# %%
plt.figure(figsize=(15,8))
plt.hist(lpgSubd.Delhi, bins=10)
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(15,4))
plt.scatter(x.Date, x.Delhi, marker='^', linewidths=10, linestyle='-', color='r')
plt.plot(x.Date, x.Delhi)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.scatter(x.Date, x.Delhi, marker='o', linewidths=10)
plt.scatter(x.Date, x.Kolkata, marker='v', linewidths=10)
plt.scatter(x.Date, x.Chennai, marker='^', linewidths=10)

plt.plot(x.Date, x.Delhi)
plt.plot(x.Date, x.Kolkata)
plt.plot(x.Date, x.Chennai)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.scatter(x.Date, x.Delhi, marker='o', linewidths=10)
plt.plot(x.Date, x.Delhi)
plt.show()

# %%
lpgSubd.head()
# Out:
#              Date      Delhi    Kolkata  Mumbai    Chennai
# 0  August 01,2017     479.77     482.58  482.08     467.35
# 1    July 11,2017  No Change  No Change  480.27  No Change
# 2    July 01,2017     477.46     480.32  491.25     465.56
# 3    June 01,2017     446.65     448.65  476.97     434.15
# 4     May 01,2017     442.77     444.77  475.56     430.27

# %%
lpgSubd.replace('No Change', np.nan, inplace=True)

# %%
lpgSubd.head()
# Out:
#              Date   Delhi Kolkata  Mumbai Chennai
# 0  August 01,2017  479.77  482.58  482.08  467.35
# 1    July 11,2017     NaN     NaN  480.27     NaN
# 2    July 01,2017  477.46  480.32  491.25  465.56
# 3    June 01,2017  446.65  448.65  476.97  434.15
# 4     May 01,2017  442.77  444.77  475.56  430.27

# %%
lpgSubd.isnull().sum()
# Out:
# Date       0
# Delhi      4
# Kolkata    4
# Mumbai     0
# Chennai    4
# dtype: int64

# %%
lpgSubd.isnull().sum()
# Out:
# Date       0
# Delhi      4
# Kolkata    4
# Mumbai     0
# Chennai    4
# dtype: int64

# %%
lpgSubd['Delhi']=lpgSubd.Delhi.astype(float)

# %%
lpgSubd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 5 columns):
# Date       80 non-null object
# Delhi      76 non-null float64
# Kolkata    76 non-null object
# Mumbai     80 non-null float64
# Chennai    76 non-null object
# dtypes: float64(2), object(3)
# memory usage: 3.2+ KB

# %%
lpgSubd['Kolkata']=lpgSubd.Kolkata.astype(float)

# %%
lpgSubd['Mumbai']=lpgSubd.Mumbai.astype(float)
lpgSubd['Chennai']=lpgSubd.Chennai.astype(float)

# %%
lpgSubd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 5 columns):
# Date       80 non-null object
# Delhi      76 non-null float64
# Kolkata    76 non-null float64
# Mumbai     80 non-null float64
# Chennai    76 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 3.2+ KB

# %%
lpgSubd.head()
# Out:
#              Date   Delhi  Kolkata  Mumbai  Chennai
# 0  August 01,2017  479.77   482.58  482.08   467.35
# 1    July 11,2017     NaN      NaN  480.27      NaN
# 2    July 01,2017  477.46   480.32  491.25   465.56
# 3    June 01,2017  446.65   448.65  476.97   434.15
# 4     May 01,2017  442.77   444.77  475.56   430.27

# %%
lpgSubd.fillna(lpgSubd.Delhi.mean(), inplace=True)

# %%
lpgSubd.Delhi.isnull().sum()
# Out:
# 0

# %%
lpgSubd.shape
# Out:
# (80, 5)

# %%
x=lpgSubd.iloc[70:80]

# %%
x
# Out:
#                  Date   Delhi  Kolkata  Mumbai  Chennai
# 70   January 29, 2009  279.70   327.05  312.05   314.55
# 71      June 09, 2008  304.70   352.05  349.50   339.60
# 72      June 09, 2008  304.70   352.05  349.50   339.60
# 73      June 05, 2008  346.30   352.05  349.50   339.60
# 74     March 01, 2007  294.75   300.50  298.00   288.10
# 75     April 01, 2005  294.75   300.50  297.95   288.15
# 76  November 05, 2004  281.60   309.65  291.85   288.15
# 77      July 01, 2004  261.60   287.95  271.30   268.10
# 78      June 16, 2004  261.60   287.95  271.30   268.10
# 79   January 01, 2004  241.60   266.70  251.00   248.55

# %%
y=lpgSubd.sort_values(['Date', 'Delhi', 'Kolkata', 'Mumbai', 'Chennai'], ascending=[False, False, False, False, False])

# %%
x=lpgSubd.sort_values(['Date'], ascending=False)

# %%
x
# Out:
#                   Date       Delhi     Kolkata  Mumbai     Chennai
# 13   September 01,2016  425.060000  427.060000  452.53  412.560000
# 29  September 01, 2015  417.820000  410.820000  456.33  405.320000
# 42  September 01, 2014  414.000000  416.000000  448.50  401.000000
# 11     October 28,2016  428.590000  430.590000  457.14  416.090000
# 40    October 23, 2014  417.000000  419.000000  452.00  404.500000
# 64    October 09, 2012  410.500000  412.500000  435.00  398.000000
# 12     October 01,2016  427.090000  429.090000  455.14  414.590000
# 28    October 01, 2015  417.820000  419.820000  454.99  405.320000
# 41    October 01, 2014  414.000000  416.000000  448.50  401.000000
# 56    October 01, 2013  410.500000  412.500000  441.00  398.000000
# 76   November 05, 2004  281.600000  309.650000  291.85  288.150000
# 10    November 01,2016  430.640000  432.640000  460.27  418.140000
# 27   November 01, 2015  417.820000  419.820000  455.82  405.320000
# ...
